# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
justin = cv2.imread('Justin.jpg')
justin1 = cv2.imread('Justin_.jpg')
justin = cv2.cvtColor(justin, cv2.COLOR_BGR2RGB)
justin1 = cv2.cvtColor(justin1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(justin1)

# %%
plt.imshow(justin)

# %%
jb_cropped = justin[0:250 , 400:650]

# %%
plt.imshow(jb_cropped)

# %%
jb_cropped.shape
# Out:
# (250, 250, 3)

# %%
justin1[50:300 , 300:550] = jb_cropped

# %%
plt.imshow(justin1)
