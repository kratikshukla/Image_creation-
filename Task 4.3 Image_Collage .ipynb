# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
justin = cv2.imread('jb.jpg')
justin1 = cv2.imread('jb1.jpg')

# %%
jb = justin[0:450 , 0:400]
jb1 = justin1[0:450 , 0:400]
jb = cv2.cvtColor(jb, cv2.COLOR_BGR2RGB)
jb1 = cv2.cvtColor(jb1, cv2.COLOR_BGR2RGB)

# %%
cv2.imshow('jb', justin)
cv2.imshow('jb1', justin1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
jb1.shape
# Out:
# (450, 400, 3)

# %%
jb.shape
# Out:
# (450, 400, 3)

# %%
collage = np.hstack(( jb , jb1 ))

# %%
plt.imshow(collage)
